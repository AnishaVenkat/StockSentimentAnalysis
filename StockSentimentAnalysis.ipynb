# %% [markdown]
# # In this project we shall the stock sentiment analysis classification problem:
#
# #There are 2 labels 0 and 1 '0' indicates stock prices going up and 1 indicates stock prices going down.

# %%
import pandas as pd

# %%
data=pd.read_csv("Data.csv",encoding="ISO-8859-1")

# %%
data.head()
# Out:
#          Date  Label                                               Top1  \
# 0  2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1  2000-01-04      0                                          Scorecard
# 2  2000-01-05      0                  Coventry caught on counter by Flo
# 3  2000-01-06      1                      Pilgrim knows how to progress
# 4  2000-01-07      1                               Hitches and Horlocks
#
#                                  Top2  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United's rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                             Top3  \
# 0                Hughes' instant hit buoys Blues
# 1                  Leader: German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# ...

# %%
data.shape
# Out:
# (4101, 27)

# %%
data.head()
# Out:
#          Date  Label                                               Top1  \
# 0  2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1  2000-01-04      0                                          Scorecard
# 2  2000-01-05      0                  Coventry caught on counter by Flo
# 3  2000-01-06      1                      Pilgrim knows how to progress
# 4  2000-01-07      1                               Hitches and Horlocks
#
#                                  Top2  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United's rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                             Top3  \
# 0                Hughes' instant hit buoys Blues
# 1                  Leader: German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# ...

# %%
# Removing extra spaces and punctuations:

data.replace("[^a-zA-Z]"," ",regex=True,inplace=True)

# %%
data['Date']
# Out:
# 0       2000-01-03
# 1       2000-01-04
# 2       2000-01-05
# 3       2000-01-06
# 4       2000-01-07
#            ...
# 4096    2016-06-27
# 4097    2016-06-28
# 4098    2016-06-29
# 4099    2016-06-30
# 4100    2016-07-01
# Name: Date, Length: 4101, dtype: object

# %%
# Splitting the training and test data:

train = data[data['Date'] < '2015-01-01']
test = data[data['Date'] > '2014-12-31']

# %%
train.head()
# Out:
#          Date  Label                                               Top1  \
# 0  2000-01-03      0  A 'hindrance to operations': extracts from the...
# 1  2000-01-04      0                                          Scorecard
# 2  2000-01-05      0                  Coventry caught on counter by Flo
# 3  2000-01-06      1                      Pilgrim knows how to progress
# 4  2000-01-07      1                               Hitches and Horlocks
#
#                                  Top2  \
# 0                           Scorecard
# 1                 The best lake scene
# 2  United's rivals on the road to Rio
# 3                 Thatcher facing ban
# 4      Beckham off but United survive
#
#                                             Top3  \
# 0                Hughes' instant hit buoys Blues
# 1                  Leader: German sleaze inquiry
# 2  Thatcher issues defence before trial by video
# 3        McIlroy calls for Irish fighting spirit
# ...

# %%
train.shape
# Out:
# (3723, 27)

# %%
test.head()
# Out:
#             Date  Label                                               Top1  \
# 3723  2015-01-02      1  Most cases of cancer are the result of sheer b...
# 3724  2015-01-05      0  Moscow-&gt;Beijing high speed train will reduc...
# 3725  2015-01-06      0                    US oil falls below $50 a barrel
# 3726  2015-01-07      1                'Shots fired' at French magazine HQ
# 3727  2015-01-08      1  New Charlie Hebdo issue to come out next week:...
#
#                                                    Top2  \
# 3723  Iran dismissed United States efforts to fight ...
# 3724  Two ancient tombs were discovered in Egypt on ...
# 3725  Toyota gives away 5,680 fuel cell patents to b...
# 3726    90% of Bibi Netanyahus Campaign Funds From U.S.
# 3727  Ahmed Merabet, Cop Killed In Paris Attacks, Wa...
#
#                                                    Top3  \
# 3723  Poll: One in 8 Germans would join anti-Muslim ...
# 3724  China complains to Pyongyang after N Korean so...
# ...

# %%
test.shape
# Out:
# (378, 27)

# %%
#Splitting independant and dependant features:

Xtrain=train.iloc[:,2:27]
Ytrain=train['Label']

Xtest=test.iloc[:,2:27]
Ytest=test['Label']

# %%
Xtrain.head(2)
# Out:
#                                                 Top1                 Top2  \
# 0  A 'hindrance to operations': extracts from the...            Scorecard
# 1                                          Scorecard  The best lake scene
#
#                               Top3                                      Top4  \
# 0  Hughes' instant hit buoys Blues  Jack gets his skates on at ice-cold Alex
# 1    Leader: German sleaze inquiry                             Cheerio, boyo
#
#                                      Top5  \
# 0  Chaos as Maracana builds up for United
# 1                The main recommendations
#
#                                                 Top6  \
# 0  Depleted Leicester prevail as Elliott spoils E...
# 1                             Has Cubie killed fees?
#
#                                Top7                               Top8  \
# 0  Hungry Spurs sense rich pickings  Gunners so wide of an easy target
# ...

# %%
#Merging all the columns into one and converting into lower case:

headlines=[]
for i in range(len(Xtrain.index)):
    headlines.append(' '.join(str(x) for x in Xtrain.iloc[i,:len(Xtrain.columns)]))

# %%
for i in range(len(headlines)):
    headlines[i]=headlines[i].lower()

# %%
headlines[0]
# Out:
# "a 'hindrance to operations': extracts from the leaked reports scorecard hughes' instant hit buoys blues jack gets his skates on at ice-cold alex chaos as maracana builds up for united depleted leicester prevail as elliott spoils everton's party hungry spurs sense rich pickings gunners so wide of an easy target derby raise a glass to strupar's debut double southgate strikes, leeds pay the penalty hammers hand robson a youthful lesson saints party like it's 1999 wear wolves have turned into lambs stump mike catches testy gough's taunt langer escapes to hit 167 flintoff injury piles on woe for england hunters threaten jospin with new battle of the somme kohl's successor drawn into scandal the difference between men and women sara denver, nurse turned solicitor diana's landmine crusade put tories in a panic yeltsin's resignation caught opposition flat-footed russian roulette sold out recovering a title"

# %%
len(headlines)
# Out:
# 3723

# %%
# Now converting the same for test data-set

headlines_test=[]
for i in range(len(Xtest.index)):
    headlines_test.append(' '.join(str(x) for x in Xtest.iloc[i,:len(Xtest.columns)]))
for i in range(len(headlines_test)):
    headlines_test[i]=headlines_test[i].lower()

# %%
headlines_test[0]
# Out:
# 'most cases of cancer are the result of sheer bad luck rather than unhealthy lifestyles, diet or even inherited genes, new research suggests. random mutations that occur in dna when cells divide are responsible for two thirds of adult cancers across a wide range of tissues. iran dismissed united states efforts to fight islamic state as a ploy to advance u.s. policies in the region: "the reality is that the united states is not acting to eliminate daesh. they are not even interested in weakening daesh, they are only interested in managing it" poll: one in 8 germans would join anti-muslim marches uk royal family\'s prince andrew named in us lawsuit over underage sex allegations some 40 asylum-seekers refused to leave the bus when they arrived at their destination in rural northern sweden, demanding that they be taken back to malm or "some big city". pakistani boat blows self up after india navy chase. all four people on board the vessel from near the pakistani port city of karachi are 
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20,20))

sns.countplot(data['Label'])
# Out:
# C:\Users\a0g0btd\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Label', ylabel='count'>

# %%
#Inference :The target feature is perfectly balanced in this dataset.

# %%
#Now lets apply NLP Count vectorizer for identifying relations betweens words for ngram=(3,3)

from sklearn.feature_extraction.text import CountVectorizer

cv=CountVectorizer(ngram_range=(3,3))

train_dt=cv.fit_transform(headlines)

test_dt=cv.transform(headlines_test)

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier(n_estimators=100,criterion='entropy')

rfc.fit(train_dt,Ytrain)

predictions=rfc.predict(test_dt)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

accuracy=accuracy_score(Ytest,predictions)
print(accuracy)
print("*"*80)

classification_report=classification_report(Ytest,predictions)
print(classification_report)
print("*"*80)

confusion_matrix=confusion_matrix(Ytest,predictions)
print(confusion_matrix)
print("*"*80)
# Out:
# 0.5132275132275133
# ********************************************************************************
#               precision    recall  f1-score   support
#
#            0       0.75      0.02      0.03       186
#            1       0.51      0.99      0.67       192
#
#     accuracy                           0.51       378
#    macro avg       0.63      0.51      0.35       378
# weighted avg       0.63      0.51      0.36       378
#
# ********************************************************************************
# [[  3 183]
#  [  1 191]]
# ********************************************************************************

# %%
#Now lets apply NLP Count vectorizer for identifying relations betweens words for ngram=(2,2)

from sklearn.feature_extraction.text import CountVectorizer

cv=CountVectorizer(ngram_range=(2,2))

train_dt=cv.fit_transform(headlines)

test_dt=cv.transform(headlines_test)

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier(n_estimators=100,criterion='entropy')

rfc.fit(train_dt,Ytrain)

predictions=rfc.predict(test_dt)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

accuracy=accuracy_score(Ytest,predictions)
print(accuracy)
print("*"*80)

classification_report=classification_report(Ytest,predictions)
print(classification_report)
print("*"*80)

confusion_matrix=confusion_matrix(Ytest,predictions)
print(confusion_matrix)
print("*"*80)
# Out:
# 0.5158730158730159
# ********************************************************************************
#               precision    recall  f1-score   support
#
#            0       0.53      0.15      0.23       186
#            1       0.51      0.88      0.65       192
#
#     accuracy                           0.52       378
#    macro avg       0.52      0.51      0.44       378
# weighted avg       0.52      0.52      0.44       378
#
# ********************************************************************************
# [[ 27 159]
#  [ 24 168]]
# ********************************************************************************
